# %%
from my_draw import *
import random
# %load_ext autoreload
# %autoreload 2

# %%
dirr = 'C:\\Users\\alexandr.pankratov\\Desktop\\noise pref\\3.5'
Settings.init(dirr,dirr,dirr,'')
onlyfiles = [f for f in os.listdir(Settings.meta_dir) if os.path.isfile(os.path.join(Settings.meta_dir, f))]
random.shuffle(onlyfiles)
for f in onlyfiles:
    a = Result(f.split(';')[0])
    print(a.meta)
    a.draw_heatmap(0,1500,15)
    a.draw_fourier(0,1500,['c3','c3.5'])
    break
# Out:
# {'Id': -2045865963, 'Du': 22.0, 'Dv': 1.0, 'p': 2.0, 'q': 2.0, 'SpaceQuant': 0.2, 'SpaceRange': 40.0, 'TimeQuant': 0.0005, 'NoiseAmp': 0.005, 'ItersNum': 4000000, 'InitStateConfig': {'ProfileType': 2, 'Avg': 1.0, 'Amp': 0.5, 'Picks': 8.0, 'Integrator': 1}, 'TimeLineQuant': 0.0125}

# %%
dirr = 'C:\\Users\\alexandr.pankratov\\Desktop\\noise pref\\2.5'
Settings.init(dirr,dirr,dirr,'')
onlyfiles = [f for f in os.listdir(Settings.meta_dir) if os.path.isfile(os.path.join(Settings.meta_dir, f))]
random.shuffle(onlyfiles)
for f in onlyfiles:
    a = Result(f.split(';')[0])
    print(a.meta)
    a.draw_heatmap(0,1500,15)
    a.draw_fourier(0,1500,['c3','c2.5'])
    break
# Out:
# {'Id': -1382737455, 'Du': 22.0, 'Dv': 1.0, 'p': 2.0, 'q': 2.0, 'SpaceQuant': 0.2, 'SpaceRange': 40.0, 'TimeQuant': 0.0005, 'NoiseAmp': 0.001, 'ItersNum': 4000000, 'InitStateConfig': {'ProfileType': 2, 'Avg': 1.0, 'Amp': 0.5, 'Picks': 3.0, 'Integrator': 1}, 'TimeLineQuant': 0.0125}

# %%
dirr = 'C:\\Users\\alexandr.pankratov\\Desktop\\noise pref\\3'
Settings.init(dirr,dirr,dirr,'')
onlyfiles = [f for f in os.listdir(Settings.meta_dir) if os.path.isfile(os.path.join(Settings.meta_dir, f))]
random.shuffle(onlyfiles)
for f in onlyfiles:
    a = Result(f.split(';')[0])
    print(a.meta)
    a.draw_heatmap(0,1500,15)
    a.draw_fourier(0,1500,['c2.5','c3','c3.5'])
    break
# Out:
# {'Id': -400120329, 'Du': 22.0, 'Dv': 1.0, 'p': 2.0, 'q': 2.0, 'SpaceQuant': 0.2, 'SpaceRange': 40.0, 'TimeQuant': 0.0005, 'NoiseAmp': 0.001, 'ItersNum': 4000000, 'InitStateConfig': {'ProfileType': 2, 'Avg': 1.0, 'Amp': 0.5, 'Picks': 9.5, 'Integrator': 1}, 'TimeLineQuant': 0.0125}
